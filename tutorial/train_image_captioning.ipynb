# %% [markdown]
# **1.Clone repository**

# %%
# !git clone https://github.com/LuongTuanAnh163002/Image_captioning.git
# Out:
# Cloning into 'Image_captioning'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 36 (delta 9), reused 14 (delta 1), pack-reused 0
# Receiving objects: 100% (36/36), 12.96 KiB | 829.00 KiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %% [markdown]
# **2.Move to Image_captioning folder**

# %%
# %cd /content/Image_captioning
# Out:
# /content/Image_captioning

# %% [markdown]
# **3.Dowload Flickr8k dataset**

# %%
# !gdown 1P-32Vfy3-s8gaAxbLqTbjLAWlKDGzbTy
d="./flickr8k/"
# !mkdir -p $d
# !unzip -q flickr8k.zip -d $d
# !rm flickr8k.zip

# %% [markdown]
# **4.Dowload weight**

# %%
# !gdown 15awWEiar47LKqHn9D4A5B_keWuxZlGTM
d="./weight_img_caption/"
# !mkdir -p $d
# !unzip -q weight_image_captioning.zip -d $d
# !rm weight_image_captioning.zip

# %% [markdown]
# **5.Train model**

# %%
# !python train.py --data data/Flicks.yaml --epochs 25 --batch_size 256 --device 0

# %% [markdown]
# **6.Dowload sample image**

# %%
# !gdown 1PWU1tw53Rv3J-T9i0OQBGFKLbMF4rg9J

# %% [markdown]
# **7.Detect with your model**

# %%
# !python detect.py --source test_predict.jpg --weight runs/train/exp

# %% [markdown]
# **8.Detect with my model**

# %%
# !python detect.py --source test_predict.jpg --weight weight_img_caption/exp
